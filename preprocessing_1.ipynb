# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\\vaishnavi potode\\OneDrive\\Desktop\\X_DSAAI_B8-main\\Python\\laptop_price.csv")

# %%
df['TouchScreen'] = df['ScreenResolution'].apply(lambda element:1 if 'Touchscreen' in element else 0)

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda element:1 if "IPS" in element else 0)

# %%
splitdf = df['ScreenResolution'].str.split('x',n = 1,expand=True)

# %%
df['X_res'] = splitdf[0]
df['Y_res'] = splitdf[1]

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df['PPI'] = (((df['X_res']**2+df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price', 'TouchScreen', 'IPS',
#        'X_res', 'Y_res', 'PPI'],
#       dtype='str')

# %%
numeric_df = df.select_dtypes(include=['number'])

# %%
numeric_df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution','Inches','X_res','Y_res'],inplace=True)

# %%
df.to_csv("C:\\Users\\amitm\\Desktop\\basic ml project\\data\\second_clean.csv", index=False)
